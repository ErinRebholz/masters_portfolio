# %% [markdown]
# ## CSCI59 - Final Project
# ### FHIR Data for Pharmacy
# #### Erin Rebholz, Spring 2024

# %% [markdown]
# ### **Imports**

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
#!pip install fhiry

# %% [markdown]
# **fhiry extracts multiple patient data files into a single data frame**
#
# #https://github.com/dermatologist/fhiry

# %%
import fhiry.parallel as fp
df_full = fp.process('data_4r/')
print(df_full.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 409973 entries, 0 to 983
# Columns: 159 entries, fullUrl to resource.organization.displaydisplay
# dtypes: float64(11), object(148)
# memory usage: 500.5+ MB
# None

# %%
#Export to excel to review quality
#df_full.iloc[:5000,:].to_csv('tester.csv')

# %%
#Replce the dots with dashes for better compatibility
df_full.columns = df_full.columns.str.replace('.','_')

# %%
len(df_full)
# Out:
# 409973

# %% [markdown]
# **Patient Data**

# %%
def patient_data_parser(df_full):
    #Create patient data data frame
    patient_data = df_full[df_full['resource_resourceType'] == 'Patient'].reset_index()
    pat_cols = ['resource_resourceType', 'id', 'resource_name', 'resource_telecom',
           'resource_gender', 'resource_birthDate', 'resource_deceasedDateTime',
           'resource_address','resource_subject_reference']
    patient_df = patient_data.loc[:,pat_cols]
    
    #Normalize to decesed date (strip time)
    patient_df['resource_deceasedDateTime_norm'] = ['1000-01-01' if type(ii)!=(str) else ii[:10] for ii in  patient_df.resource_deceasedDateTime]
    #Parse Resource Address into Sub-fields
    patient_df['resource_address_line'] = [pd.json_normalize(x).loc[0,'line'][0] for x in patient_df['resource_address']] 
    patient_df['resource_address_city'] = [pd.json_normalize(x).loc[0,'city'] for x in patient_df['resource_address']] 
    patient_df['resource_address_state'] = [pd.json_normalize(x).loc[0,'state'] for x in patient_df['resource_address']] 
    ### Note that not all entries had 'postal code' so we need to assign "" in the second line
    patient_df['resource_address_postalCode'] = [pd.json_normalize(x).iloc[0,4] for x in patient_df['resource_address']] 
    patient_df['resource_address_postalCode'] = ["" if x == 'US' else x for x in patient_df['resource_address_postalCode']]
    patient_df['resource_address_country'] = [pd.json_normalize(x).loc[0,'country'] for x in patient_df['resource_address']] 

    #Parse Resource Name into sub-fields
    patient_df['resource_name_given'] = [pd.json_normalize(x).iloc[0,1] for x in patient_df['resource_name']]
    patient_df['resource_name_family'] = [pd.json_normalize(x).iloc[0,2][0] for x in patient_df['resource_name']] #Enclosed in brackets
    #Extract phone info from telecom
    patient_df['resource_telecom_phone'] = [pd.json_normalize(x).iloc[0,1] for x in patient_df['resource_telecom']] 

    
    #Reorder columns and get rid of unnecessary columns
    cols = [ 'id', 'resource_name_given','resource_name_family',
           'resource_gender', 'resource_birthDate', 'resource_deceasedDateTime',
            'resource_address_line', 'resource_address_city',
           'resource_address_state', 'resource_address_postalCode',
           'resource_address_country',  'resource_telecom_phone']
    
    patient_df = patient_df.loc[:,[ 'id', 'resource_name_given','resource_name_family',
           'resource_gender', 'resource_birthDate', 'resource_deceasedDateTime_norm',
            'resource_address_line', 'resource_address_city',
           'resource_address_state', 'resource_address_postalCode',
           'resource_address_country',  'resource_telecom_phone']]
    
    #rename columns to friendly names
    patient_df.columns = [ 'patient_id', 'given_name','family_name',
           'gender', 'birth_date', 'deceased_date',
            'street_address', 'city',
           'state', 'postal_code',
           'country',  'phone']
    
    return patient_df

# %%
patient_df = patient_data_parser(df_full)

# %%
#check Encounter_ID is unique
len(patient_df), len(patient_df.patient_id.unique())
# Out:
# (555, 555)

# %%
patient_df.to_csv('tables/patient_table.csv', index = False)

# %%
patient_df.head()
# Out:
#                              patient_id  given_name  family_name  gender  \
# 0  b0a06ead-cc42-aa48-dad6-841d4aa679fa   Harris789     Abdul218    male
# 1  ccfc4db2-2026-7adb-3db0-33f3828140bb  Schmidt332       Abe604    male
# 2  31a2e8ec-69fc-8a71-3ab6-36cbdd508713  DuBuque211  Adelaida985  female
# 3  71a8b156-760b-df6b-859e-eefc7932a526    Hintz995   Adriana394  female
# 4  76b289fd-e825-734c-8446-316f59643593  Gerhold939    Agueda283  female
#
#    birth_date deceased_date            street_address     city state  \
# 0  1952-12-05    2002-02-01     572 Keebler Esplanade   Boston    MA
# 1  1976-06-06    1000-01-01            768 Mertz Camp  Peabody    MA
# 2  1917-05-15    2017-02-18            848 Casper Way   Quincy    MA
# 3  2014-11-15    1000-01-01  455 Bayer Rapid Suite 75   Boston    MA
# 4  1985-03-03    1000-01-01   733 Bednar Grove Apt 36   Boston    MA
#
#   postal_code country         phone
# 0       02134      US  555-443-1041
# 1       01940      US  555-345-5342
# 2       02169      US  555-925-4660
# 3       02120      US  555-237-5240
# 4       02115      US  555-831-3391

# %% [markdown]
# **Observation**

# %%
def obs_data_parser(df_full):

    #Create observation data data frame
    obs_data = df_full[df_full['resource_resourceType'] == 'Observation'].reset_index()
    
    #Select columns for exploration
    obs_cols = [1,2,3,18,23,29,32,35,36,47,65,72,73,75]
    obs_df = obs_data.iloc[:, obs_cols]
    
    #Normalize date
    obs_df['effective_date'] = [ii if type(ii)!=(str) else ii[:10] for ii in  obs_df.resource_effectiveDateTime]
    
    #Truncate Encounter and Patient Reference Keys to Link Back to Other Table's Formats
    obs_df['encounter_id'] = [ii[9:] for ii in obs_df.resource_encounter_reference]
    obs_df['patient_id'] = [ii[9:] for ii in obs_df.resource_subject_reference]
    
    #Observation Code (strip unneeded data and normalize json dictionary stuff
    obs_df['obs_code'] = [pd.json_normalize(pd.json_normalize(x).iloc[0,0]).iloc[0,1] for x in obs_df['resource_category']]  # this is slow, refactor?
    
    
    #Reshuffle columns and remove not needed columns)
    obs_cols = ['id', 'encounter_id', 'patient_id', 'effective_date',
           'obs_code','resource_code_text',
           'resource_valueQuantity_value', 'resource_valueQuantity_unit',
           'resource_valueQuantity_code']
    
    obs_df = obs_df.loc[:,obs_cols]
    
    #rename columns to friendly names
    obs_df.columns = ['obs_id', 'encounter_id', 'patient_id', 'effective_date', 'obs_code',
                      'code_text', 'quantity_value',
                      'quantity_unit', 'quantity_code']

    return obs_df

# %%
obs_df = obs_data_parser(df_full)
# Out:
# C:\Users\erinr\AppData\Local\Temp\ipykernel_14224\2799416663.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_df['effective_date'] = [ii if type(ii)!=(str) else ii[:10] for ii in  obs_df.resource_effectiveDateTime]
# C:\Users\erinr\AppData\Local\Temp\ipykernel_14224\2799416663.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_df['encounter_id'] = [ii[9:] for ii in obs_df.resource_encounter_reference]
# C:\Users\erinr\AppData\Local\Temp\ipykernel_14224\2799416663.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_df['patient_id'] = [ii[9:] for ii in obs_df.resource_subject_reference]
# C:\Users\erinr\AppData\Local\Temp\ipykernel_14224\2799416663.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_df['obs_code'] = [pd.json_normalize(pd.json_normalize(x).iloc[0,0]).iloc[0,1] for x in obs_df['resource_category']]  # this is slow, refactor?

# %%
#check Observation_ID is unique
len(obs_df), len(obs_df.obs_id.unique())
# Out:
# (131703, 131703)

# %%
obs_df.to_csv('tables/obs_table.csv', index= False)

# %%
obs_df.head()
# Out:
#                                  obs_id                          encounter_id  \
# 0  33648be3-5286-a324-312c-c9cf3cfedac8  d331b9e7-cc03-6a74-ecac-64fedddb57a9
# 1  a5cd0f82-45c2-1f1c-b5cb-24d317cfa74b  d331b9e7-cc03-6a74-ecac-64fedddb57a9
# 2  75a7476a-de6c-ce31-5b47-e5e72e7c4211  d331b9e7-cc03-6a74-ecac-64fedddb57a9
# 3  26945d93-ed09-2c27-55d2-698657b29dcf  d331b9e7-cc03-6a74-ecac-64fedddb57a9
# 4  fa2b75e0-a7aa-5fdb-34d8-c88c3addc246  d331b9e7-cc03-6a74-ecac-64fedddb57a9
#
#                              patient_id effective_date     obs_code  \
# 0  b0a06ead-cc42-aa48-dad6-841d4aa679fa     1992-04-10  vital-signs
# 1  b0a06ead-cc42-aa48-dad6-841d4aa679fa     1992-04-10  vital-signs
# 2  b0a06ead-cc42-aa48-dad6-841d4aa679fa     1992-04-10  vital-signs
# 3  b0a06ead-cc42-aa48-dad6-841d4aa679fa     1992-04-10  vital-signs
# 4  b0a06ead-cc42-aa48-dad6-841d4aa679fa     1992-04-10  vital-signs
#
#                                            code_text  quantity_value  \
# 0                                        Body Height          186.00
# 1  Pain severity - 0-10 verbal numeric rating [Sc...            1.00
# 2                                        Body Weight          102.80
# 3                                    Body Mass Index           29.71
# 4                                     Blood Pressure             NaN
#
#   quantity_unit quantity_code
# 0            cm            cm
# 1       {score}       {score}
# 2            kg            kg
# 3         kg/m2         kg/m2
# 4           NaN           NaN

# %% [markdown]
# **Encounter**

# %%
def encounter_data_parser(df_full):

    enc_data = df_full[df_full['resource_resourceType'] == 'Encounter'].reset_index()
    
    #Select columns for exploration
    enc_cols = ['id','resource_class_code','resource_type','resource_subject_reference',
                'resource_participant','resource_period_start','resource_period_end','resource_location']
    
    enc_df = enc_data.loc[:, enc_cols]
    
    #normalize Date times to dates
    enc_df['start_date'] = [ii if type(ii)!=(str) else ii[:10] for ii in  enc_df.resource_period_start]
    enc_df['end_date'] = [ii if type(ii)!=(str) else ii[:10] for ii in  enc_df.resource_period_end]
    
    #visit info
    enc_df['snomed_code'] = [pd.json_normalize(pd.json_normalize(x).loc[0,'coding'][0])['code'][0] for x in enc_df['resource_type']]
    enc_df['snomed_text'] = [pd.json_normalize(pd.json_normalize(x).loc[0,'coding'][0])['display'][0] for x in enc_df['resource_type']]
    
    #provider info
    enc_df['provider_NPI'] = [pd.json_normalize(x)['individual.reference'][0][-10:]  for x in enc_df.resource_participant]
    enc_df['provider_name'] = [pd.json_normalize(x)['individual.display'][0]  for x in enc_df.resource_participant]
    
    #facility info
    enc_df['facility_name'] = [pd.json_normalize(x)['location.display'][0]  for x in enc_df.resource_location]
    
    #patient id
    enc_df['patient_id'] = [ii[9:] for ii in enc_df.resource_subject_reference]
    
    
    #shuffle and remove column names
    enc_df_cols = ['id', 'patient_id', 'start_date', 'end_date','snomed_code', 'snomed_text', 'provider_NPI',
                   'provider_name', 'facility_name','resource_class_code']
    
    enc_df = enc_df.loc[:,enc_df_cols]
    
    #rename columns to friendly names
    enc_df.columns = ['encounter_id', 'patient_id', 'start_date', 'end_date', 
           'snomed_code', 'snomed_text', 'provider_NPI', 'provider_name',
           'facility_name','facility_code']
    return enc_df

# %%
enc_df = encounter_data_parser(df_full)

# %%
enc_df.to_csv('tables/enc_table.csv', index = False)

# %%
#check Encounter_ID is unique
len(enc_df), len(enc_df.encounter_id.unique())
# Out:
# (27812, 27812)

# %%
enc_df.head(3)
# Out:
#                            encounter_id                            patient_id  \
# 0  a889805b-20ca-0ba6-5b5c-e617ce99b0cc  b0a06ead-cc42-aa48-dad6-841d4aa679fa
# 1  b1ca5d4d-e3b5-e65b-e900-3844ae30f421  b0a06ead-cc42-aa48-dad6-841d4aa679fa
# 2  853a4e65-da0d-d531-eb6e-458a70bcf552  b0a06ead-cc42-aa48-dad6-841d4aa679fa
#
#    start_date    end_date snomed_code            snomed_text provider_NPI  \
# 0  1954-04-03  1954-04-03   185347001  Encounter for problem   9999999989
# 1  1954-04-20  1954-04-20   185347001  Encounter for problem   9999999989
# 2  1959-06-03  1959-06-03   185345009  Encounter for symptom   9999999989
#
#              provider_name          facility_name facility_code
# 0  Dr. Lesley194 Fisher429  MOUNT AUBURN HOSPITAL           AMB
# 1  Dr. Lesley194 Fisher429  MOUNT AUBURN HOSPITAL           AMB
# 2  Dr. Lesley194 Fisher429  MOUNT AUBURN HOSPITAL           AMB

# %% [markdown]
# **Medication History**

# %%
def medication_data_parser(df_full):
    med_data = df_full[df_full['resource_resourceType'] == 'MedicationRequest'].reset_index()
        
    #Select columns for exploration
    med_cols_raw = ['id','resource_status','resource_subject_reference','resource_encounter_reference',
                    'resource_intent','resource_medicationCodeableConcept_text', 'resource_authoredOn',
                    'resource_requester_reference','resource_prescription_reference','patientId',
                    'resource_medicationCodeableConcept_codingcodes','resource_dosageInstruction']
    
    med_df = med_data.loc[:, med_cols_raw]
    
    #normalize Date times to dates
    med_df['request_date'] = [ ii[:10] for ii in  med_df.resource_authoredOn]
    
    #Truncate Encounter and Patient Reference Keys to Link Back to Other Table's Formats
    med_df['encounter_id'] = [ii[9:] for ii in med_df.resource_encounter_reference]
    med_df['patient_id'] = [ii[9:] for ii in med_df.resource_subject_reference]
    
    #Rx_Norm
    med_df['rxnorm_code'] = med_df.resource_medicationCodeableConcept_codingcodes.astype('str').str.strip('[').str.strip(']').str.strip("'")
    med_df['rxnorm_text'] =  med_df.resource_medicationCodeableConcept_text.replace(',',' ')
    
    #NPI
    med_df['provider_id'] = [x[-10:] for x in med_df.resource_requester_reference]
    
    
    ###Dosing Instructions
    text = []
    snomed_code = []
    snomed_text = []
    repeat_freq = []
    repeat_period = []
    repeat_period_unit = []
    as_needed = []
    
    for ii in range(len(med_df.resource_dosageInstruction)):
        try:
            helper = med_df.resource_dosageInstruction[ii][0]['text']
            text.append(helper)
        except: 
            text.append("")
    
        try: 
            helper = med_df.resource_dosageInstruction[ii][0]['timing']
            helper1 = helper['repeat']['frequency']
            helper2 = helper['repeat']['period']
            helper3 = helper['repeat']['periodUnit']
            
            repeat_freq.append(helper1)
            repeat_period.append(helper2)
            repeat_period_unit.append(helper3)
        except: 
            repeat_freq.append("")
            repeat_period.append("")
            repeat_period_unit.append("")
        
        try:
            helper = med_df.resource_dosageInstruction[100][0]['asNeededBoolean']
            as_needed.append(helper)
        except: 
            as_needed.append("")
    
        try:
            helper = med_df.resource_dosageInstruction[ii][0]['additionalInstruction'][0]['coding'][0]['code'] #snomed code
            snomed_code.append(helper)
            helper = med_df.resource_dosageInstruction[ii][0]['additionalInstruction'][0]['coding'][0]['display'] #snomed text
            snomed_text.append(helper)
        except:
            snomed_code.append('')
            snomed_text.append('')
    
    med_df['rx_text'] = text
    med_df['snomed_code'] = snomed_code
    med_df['snomed_text'] = snomed_text
    med_df['repeat_freq'] = repeat_freq
    med_df['repeat_period'] = repeat_period
    med_df['repeat_period_unit'] = repeat_period_unit
    med_df['as_needed'] = as_needed
       
    med_df['rx_text'] =  med_df.rx_text.replace(',',' ')
    
    #Reorder columns and omit unnecessary values:
    med_cols = ['id', 'resource_status', 'patient_id', 'provider_id', 'encounter_id',
                'request_date', 'rxnorm_code', 'rxnorm_text','rx_text',
                'snomed_code', 'snomed_text', 'repeat_freq', 'repeat_period','repeat_period_unit', 'as_needed']
    
    
    med_df = med_df.loc[:,med_cols]

    med_df.columns = ['rx_id', 'resource_status', 'patient_id', 'provider_id', 'encounter_id',
                'request_date', 'rxnorm_code', 'rxnorm_text','rx_text',
                'snomed_code', 'snomed_text', 'repeat_freq', 'repeat_period','repeat_period_unit', 'as_needed']
    
    return med_df

# %%
med_df = medication_data_parser(df_full)

# %%
med_df.to_csv('tables/med_history.csv', index = False, encoding='utf-8',quotechar = '"')

# %%
#check Rx_ID is unique
len(med_df), len(med_df.rx_id.unique())
# Out:
# (24256, 24256)

# %%
med_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24256 entries, 0 to 24255
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   rx_id               24256 non-null  object
#  1   resource_status     24256 non-null  object
#  2   patient_id          24256 non-null  object
#  3   provider_id         24256 non-null  object
#  4   encounter_id        24256 non-null  object
#  5   request_date        24256 non-null  object
#  6   rxnorm_code         24256 non-null  object
#  7   rxnorm_text         23902 non-null  object
#  8   rx_text             24256 non-null  object
#  9   snomed_code         24256 non-null  object
#  10  snomed_text         24256 non-null  object
#  11  repeat_freq         24256 non-null  object
#  12  repeat_period       24256 non-null  object
#  13  repeat_period_unit  24256 non-null  object
#  14  as_needed           24256 non-null  bool
# dtypes: bool(1), object(14)
# memory usage: 2.6+ MB

# %%
med_df['rxnorm_text'] =  med_df.rxnorm_text.str.strip(',')
#med_df['rxnorm_code'] = med_df.resource_medicationCodeableConcept_codingcodes.str.strip('[').str.strip(']')

# %%
med_df.head()
# Out:
#                                   rx_id resource_status  \
# 0  c0e50da8-7aed-f2db-f893-efe740504150         stopped
# 1  28fe47d9-82cf-c35d-468d-39ecd61c3b9c         stopped
# 2  4d93f56b-3db5-e0a6-a4c7-f65cf2b8538d         stopped
# 3  9f5c47fb-b639-e236-ea1a-b6bc2fcab325         stopped
# 4  e7a52e7d-d8ec-5824-b4a6-bb936b2f299a         stopped
#
#                              patient_id provider_id  \
# 0  b0a06ead-cc42-aa48-dad6-841d4aa679fa  9999999989
# 1  b0a06ead-cc42-aa48-dad6-841d4aa679fa  9999999989
# 2  b0a06ead-cc42-aa48-dad6-841d4aa679fa  9999999989
# 3  b0a06ead-cc42-aa48-dad6-841d4aa679fa  9999999989
# 4  b0a06ead-cc42-aa48-dad6-841d4aa679fa  9999968019
#
#                            encounter_id request_date rxnorm_code  \
# 0  d331b9e7-cc03-6a74-ecac-64fedddb57a9   1992-04-10      312961
# 1  d331b9e7-cc03-6a74-ecac-64fedddb57a9   1992-04-10      705129
# 2  d331b9e7-cc03-6a74-ecac-64fedddb57a9   1992-04-10      705129
# 3  d331b9e7-cc03-6a74-ecac-64fedddb57a9   1992-04-10      312961
# 4  f2f337b4-33bb-1fe1-4f96-8102f9a8b75a   1992-04-24      705129
#
#                                  rxnorm_text rx_text snomed_code snomed_text  \
# 0              Simvastatin 20 MG Oral Tablet
# 1  Nitroglycerin 0.4 MG/ACTUAT Mucosal Spray
# 2  Nitroglycerin 0.4 MG/ACTUAT Mucosal Spray
# 3              Simvastatin 20 MG Oral Tablet
# 4  Nitroglycerin 0.4 MG/ACTUAT Mucosal Spray
#
#   repeat_freq repeat_period repeat_period_unit  as_needed
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False

# %% [markdown]
# **Allergy**

# %%
def allergy_data_parser(df_full):

    #Create allergy data frame
    al_data = df_full[df_full['resource_resourceType'] == 'AllergyIntolerance'].reset_index()
    
    #Select columns for exploration
    al_cols_raw = ['resource_resourceType', 'id', 'request_url', 'resource_type',
           'resource_category', 'resource_patient_reference',
           'resource_criticality', 'resource_code_text', 'resource_recordedDate',
           'resource_reaction']
        
    al_df = al_data.loc[:, al_cols_raw]
    
    #normalize Date times to dates
    al_df['recorded_date'] = [ ii[:10] for ii in  al_df.resource_recordedDate]
        
    #Truncate Patient Reference Keys to Link Back to Other Table's Formats
    al_df['patient_id'] = [ii[9:] for ii in al_df.resource_patient_reference]

    al_df['resource_category'] = al_df.resource_category.astype('str').str.strip('[').str.strip(']').str.strip("'")
    
    ## Get allergy symptoms from nested JSON column
    text = []
    
    for ii in range(len(al_df.resource_reaction)):
        try:
            helper = ""
            for i in range(len(al_df.iloc[ii,9])):
                helper = helper + (f"{i+1}: {al_df.iloc[ii,9][i]['manifestation'][0]['coding'][0]['display']} ")
            text.append(helper)
        except: 
            text.append("")
    
    al_df['reaction'] = text
    
    #Reorder columns and omit unnecessary values:
    al_cols = ['id', 'patient_id', 'recorded_date','resource_category', 'resource_code_text', 'reaction', 'resource_criticality']
        
    al_df = al_df.loc[:,al_cols]
    
    al_df.columns = ['allergy_id', 'patient_id', 'recorded_date','allergy_category', 'allergy_details', 'reaction', 'allergy_criticality']
    
    return al_df

# %%
al_df = allergy_data_parser(df_full)

# %%
al_df.to_csv('tables/allergy_table.csv',index = False, encoding='utf-8')

# %%
#check Allergy_ID is unique
len(al_df), len(al_df.allergy_id.unique())
# Out:
# (499, 499)

# %%
al_df.allergy_criticality.value_counts()
# Out:
# allergy_criticality
# low    499
# Name: count, dtype: int64

# %%
al_df.head()
# Out:
#                                allergy_id  \
# 9    7f020d47-51c8-740e-5233-1a6ef6484ddb
# 168  738f95d5-e2c3-c8e8-bdd9-61eba55a4ad6
# 9    5692c338-6acd-0a43-7a77-ca3e3cfbf370
# 10   44c35163-e3a9-05f1-aeda-4bb52e700a84
# 11   2efa474b-ffe8-6013-042c-8043c36f55a1
#
#                               patient_id recorded_date allergy_category  \
# 9    0a06ead-cc42-aa48-dad6-841d4aa679fa    1954-04-20             food
# 168  2fb7efc-5cfd-f8d3-927b-42f8ee099531    2014-12-14             food
# 9    46a1435-2455-914f-c287-7b88052d05db    1983-05-11      environment
# 10   46a1435-2455-914f-c287-7b88052d05db    1983-05-11      environment
# 11   46a1435-2455-914f-c287-7b88052d05db    1983-05-11      environment
#
#                 allergy_details  \
# 9     Eggs (edible) (substance)
# 168            Fish (substance)
# 9               Mold (organism)
# 10   House dust mite (organism)
# 11    Animal dander (substance)
#
#                                               reaction allergy_criticality
# 9                                                                      low
# 168  1: Dyspnea (finding) 2: Finding of vomiting (f...                 low
# 9                               1: Allergic skin rash                  low
# 10                                                                     low
# 11   1: Eruption of skin (disorder) 2: Wheal (findi...                 low

# %% [markdown]
# ### **Patient Data Loading for SQL**

# %% [markdown]
# **Search for patients with insulin perscriptions**

# %%
#Patients with active insulin prescriptons
diabetes_patients = med_df[(med_df.rxnorm_text.str.contains('insulin')) &(med_df.resource_status == 'active')].patient_id.unique()
diabetes_patients
# Out:
# array(['9e84e569-7adc-ff42-ccdb-9fe9c23842a6',
#        '060e72d3-912e-55cd-0c92-5faa6cb7a6db',
#        '8c6ae452-5f8c-9ff6-006d-c6c860acf5cd',
#        'be82309d-1a8f-df82-4cd6-5f03e1060e8e',
#        '3dfce025-b696-711a-8c2d-6903736e2882',
#        '55c5b8d3-99d0-58ad-8444-e42bb81bd5c7',
#        'ed803173-5e55-aecd-5055-591164ee3005',
#        'ef167059-cef0-12c4-49db-993ca3a20c01',
#        'fa2d28b1-de84-ac96-ee04-a20dc54832c1',
#        'e23c7a6e-6ef2-3932-1361-b73b4c8a3961',
#        'd57e867e-4896-9e07-f502-5f4f881bd80e'], dtype=object)

# %%
patient_sample =  patient_df[patient_df.patient_id.isin(diabetes_patients)]
len(patient_sample)
# Out:
# 11

# %%
#List of past medications
med_sample = med_df[med_df.patient_id.isin(diabetes_patients)]
active_med_sample = med_df[(med_df.patient_id.isin(diabetes_patients)) &(med_df.resource_status == 'active')]

len(med_sample),len(active_med_sample)
# Out:
# (6935, 66)

# %%
code_text_samples = ['Body Weight', 'Body Mass Index','Blood Pressure','Hemoglobin A1c/Hemoglobin.total in Blood','Total Cholesterol',
                     'Low Density Lipoprotein Cholesterol','High Density Lipoprotein Cholesterol','Creatinine','Microalbumin Creatinine Ratio',
                    'Creatinine [Mass/volume] in Serum or Plasma']

obs_sample = obs_df[(obs_df.patient_id.isin(diabetes_patients))&(obs_df.code_text.isin(code_text_samples))]
len(obs_sample)
# Out:
# 5035

# %%
enc_sample = enc_df[enc_df.patient_id.isin(diabetes_patients)]
len(enc_sample)
# Out:
# 3996

# %%
al_sample = al_df[al_df.patient_id.isin(diabetes_patients)]
len(al_sample)
# Out:
# 5

# %% [markdown]
# **Create a function to generate the sql text to insert patient**

# %%
sql_list = []

encounter = True
med_history = True
observation = True
allergy = True

for i in range(len(diabetes_patients)):
#for i in range(1):  #limited # of patients
    #Generate new patient text
    small_df = patient_sample[patient_sample.patient_id == diabetes_patients[i]]

    for j in range(patient_sample.shape[1]):
        if j == 0:
            text = '"'+small_df.iloc[0,j]+'"'
        else:   
            text = text+' ,"'+small_df.iloc[0,j]+'"'

    helper = f'INSERT INTO patient(patient_id, given_name, family_name, gender, birth_date, deceased_date,street_address,city,state,postal_code, country, phone) VALUES ({text});'
    
    sql_list.append(helper)

    #Generate encounter data set
    if encounter == True:
        small_df = enc_sample[enc_sample.patient_id == diabetes_patients[i]]
        for k in range(small_df.shape[0]):
            for j in range(small_df.shape[1]):
                if j == 0:
                    text = '"'+small_df.iloc[k,j]+'"'
                else:   
                    text = text+' ,"'+small_df.iloc[k,j]+'"'
            
            helper = f'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ({text});'
            sql_list.append(helper)    
    else:
        pass
        
    #Generate med history data set
    if med_history == True:
        small_df = med_sample[med_sample.patient_id == diabetes_patients[i]]
        for k in range(small_df.shape[0]):
            for j in range(small_df.shape[1]):
                if j == 0:
                    text = '"'+small_df.iloc[k,j]+'"'
                else:   
                    text = text+' ,"'+str(small_df.iloc[k,j])+'"'
            
            helper = f'INSERT INTO med_history(rx_id, resource_status,	patient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ({text});'
            sql_list.append(helper)
    else:
        pass
        
    #Generate observation data set
    if observation == True:
        small_df = obs_sample[obs_sample.patient_id == diabetes_patients[i]]
        for k in range(small_df.shape[0]):
            for j in range(small_df.shape[1]):
                if j == 0:
                    text = '"'+small_df.iloc[k,j]+'"'
                else:   
                    text = text+' ,"'+str(small_df.iloc[k,j])+'"'
                
            helper = f'INSERT INTO observation (obs_id, encounter_id, patient_id, effective_date, obs_code, code_text, quantity_value, quantity_unit, quantity_code) VALUES ({text});'
            sql_list.append(helper)
    else:
        pass

    #Generate allergy data set
    if allergy == True:
        small_df = al_sample[al_sample.patient_id == diabetes_patients[i]]
        for k in range(small_df.shape[0]):
            for j in range(small_df.shape[1]):
                if j == 0:
                    text = '"'+small_df.iloc[k,j]+'"'
                else:   
                    text = text+' ,"'+str(small_df.iloc[k,j])+'"'
                
            helper = f'INSERT INTO allergy (allergy_id, patient_id, recorded_date, allergy_category, allergy_details, reaction, allergy_criticality) VALUES ({text});'
            sql_list.append(helper)

    else:
        pass

# %%
sql_list
# Out:
# ['INSERT INTO patient(patient_id, given_name, family_name, gender, birth_date, deceased_date,street_address,city,state,postal_code, country, phone) VALUES ("9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"Hilll811" ,"Armando772" ,"male" ,"1945-11-04" ,"1000-01-01" ,"397 Rodriguez Promenade Suite 93" ,"Lynn" ,"MA" ,"01902" ,"US" ,"555-296-4764");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("f42b5a45-0e30-c707-4618-14ba9e107390" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1963-12-29" ,"1963-12-29" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("b85d8e8a-67aa-9d12-1038-76b34f73c330" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1964-01-28" ,"1964-01-28" ,"390906007" ,"Hypertension follow-up encounter" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("8a77621e-aa46-dfc9-389f-2e96cb62f8e3" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1965-01-03" ,"1965-01-03" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("d03f38e0-499f-f691-344a-6a1cd5cb67c3" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1966-01-09" ,"1966-01-09" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("abbea18d-b380-27bc-a957-1919ac356c00" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1967-01-15" ,"1967-01-15" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("3a4322fb-d7d0-6393-b411-d703a01a646f" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1968-01-21" ,"1968-01-21" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("d0b87ec3-a254-b7d1-4879-01b37a794c79" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1969-01-26" ,"1969-01-26" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("1022d56b-581f-3d77-03f7-088762f51c1f" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1970-02-01" ,"1970-02-01" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("8ae93c19-0c73-dbb4-9046-7b30b5b1a821" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1971-02-07" ,"1971-02-07" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("c656694f-a9ee-dd37-0373-253fd4a79170" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1972-02-13" ,"1972-02-13" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("1e90bb9b-1d9d-babd-3af6-2a45c736b1a0" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1973-02-18" ,"1973-02-18" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("94a549e9-5a26-0f14-a78e-197de5a865c2" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1974-02-24" ,"1974-02-24" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("9cc48887-7794-8861-2c1e-75b2b001a1ce" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1975-03-02" ,"1975-03-02" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("430d1a7d-5ec7-40bb-bc23-2b5b6066f335" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1976-03-07" ,"1976-03-07" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("14b516f5-3f9c-8b6c-459c-42e7ac640e0d" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1977-03-13" ,"1977-03-13" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("30dd9683-931d-0835-c755-63f46a857c7b" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1978-03-19" ,"1978-03-19" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("02eb664c-60ea-22b4-7a7b-a43561dc215e" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1979-03-25" ,"1979-03-25" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("283b8cc9-7dce-984b-e78d-1d937710bd67" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1980-03-30" ,"1980-03-30" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("666a39d6-3b86-db9f-bcf5-8055fe585616" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1980-04-13" ,"1980-04-13" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("2f8ee1de-a860-2a41-5b75-3e72cc705beb" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1980-04-16" ,"1980-04-16" ,"185345009" ,"Encounter for symptom" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("417e50e1-f8fa-7ebf-b8b9-c048b57af4f6" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1981-04-05" ,"1981-04-05" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("dc9ea6f9-61d6-6608-726b-de36e138aa62" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1982-04-11" ,"1982-04-11" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("7a31e3f7-0c3e-59db-903a-0ffc65588b06" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1983-04-17" ,"1983-04-17" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("a3ea8a68-b3c4-79f3-6def-f4841b3c39e7" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1984-04-22" ,"1984-04-22" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("bd5e4153-60ab-1c6c-5271-a614519f187b" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1985-04-28" ,"1985-04-28" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("eaf23b76-ad17-a72c-7c88-665851d42919" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1986-05-04" ,"1986-05-04" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("2a4164f1-585c-36e4-2c9d-fe47f43bdc17" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1987-05-10" ,"1987-05-10" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("e5938777-b288-1cdf-24b1-a805e2fc664e" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1988-05-15" ,"1988-05-15" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("8349543a-59d8-60dc-fa93-cd2065f776cc" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1989-05-21" ,"1989-05-21" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("ba1ce5dc-f9cc-0510-ec35-911257294eb1" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1990-05-27" ,"1990-05-27" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("9077b874-4cd3-b8a2-ba6e-791342e66535" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1991-06-02" ,"1991-06-02" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("0ff16ae5-9519-b223-87b5-7e9a5d228165" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1992-06-07" ,"1992-06-07" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("14b3faa1-05ee-a90e-c812-bac1257e26e9" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1993-06-13" ,"1993-06-13" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("2d08f29e-6bb8-6a93-418e-abbcd826bad5" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1993-06-13" ,"1993-06-13" ,"185347001" ,"Encounter for problem" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("ceba8621-c630-3b27-98ef-b98d47ceca82" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1994-06-19" ,"1994-06-19" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("5a79114c-1746-1bea-e817-65133032ca45" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1995-06-25" ,"1995-06-25" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("c87cd5bb-f5d2-9a09-df77-e9b818585ea6" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1996-06-30" ,"1996-06-30" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("4e8ed268-955f-d129-49c1-8fa5e6155863" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1997-07-06" ,"1997-07-06" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("674350ed-367f-7f0f-54ef-5c1c5bfa9e48" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1998-07-12" ,"1998-07-12" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("e255a53c-d2dd-7517-267d-05031779c8a6" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"1999-07-18" ,"1999-07-18" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("1e88f230-1be0-27f2-94d1-6dba0eef4f3d" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2000-07-23" ,"2000-07-23" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("758aa1ae-01fe-edf7-d810-a86d62aa481e" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2000-08-06" ,"2000-08-06" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("0eb0467d-4448-09c1-89da-a5b9b04055a5" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2001-02-18" ,"2001-02-18" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("f823e492-a2c8-3947-ebc9-09cc6797ba51" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2001-03-25" ,"2001-03-25" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("69322d76-b04f-d9ca-5ef3-df4a1f6f394a" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2001-07-29" ,"2001-07-29" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("ee309830-a38f-f9bf-5e43-5c01701a4c0a" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2002-01-20" ,"2002-01-20" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("cb7568d1-3b72-8a4d-9675-f4629d9c6fe1" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2002-08-04" ,"2002-08-04" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("339efbe6-f760-0d6e-0132-a5dd85801380" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2002-12-15" ,"2002-12-15" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("2fa5ea09-a872-085d-5f75-e81ce2b4f437" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2003-08-10" ,"2003-08-10" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("95881c4f-2212-b666-1a54-d8b1256ce7c8" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2003-08-24" ,"2003-08-24" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("65ccd6cb-a426-f94e-2c4f-af38d1c99f7b" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2003-12-07" ,"2003-12-07" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("363103bb-af0e-87b4-43af-615400ba22d9" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2004-08-15" ,"2004-08-15" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("fbdc3628-f23e-8f34-25e1-8bfbe27a2df2" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2005-08-21" ,"2005-08-21" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("6f09746b-adfd-09da-118b-d6291b020e23" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2006-03-26" ,"2006-03-26" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("5fae3d69-dcfe-f32d-ba12-aad28cef7a84" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2006-06-25" ,"2006-06-25" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("9aa0bca1-96d1-7a9f-b8aa-676b6cbe1382" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2006-08-27" ,"2006-08-27" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("0ca2e51e-4b69-741c-0495-9462cee7be49" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2007-09-02" ,"2007-09-02" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("1a28bb39-0d09-c601-9589-922a8cc0a750" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2007-12-16" ,"2007-12-16" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("d5e59e14-ba37-6703-446f-4fcbfc85c142" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2008-04-13" ,"2008-04-13" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("b89c405d-e6f9-00a7-fb6a-6b6e9c44d649" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2008-08-10" ,"2008-08-10" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("7098555a-2e85-3ca5-46e9-a98fdaf4fe1f" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2008-09-07" ,"2008-09-07" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("273fe81c-68b9-0f8d-ebe4-2011bb4bdb38" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2008-09-21" ,"2008-09-21" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("14174929-582f-daeb-18fe-37cecb143c6c" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2008-11-09" ,"2008-11-09" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("72e54fe9-ad8b-85a5-0237-b639c8aab430" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2009-01-11" ,"2009-01-11" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("20c6e055-7bfb-d0e8-669b-2dba1e230f4a" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2009-02-08" ,"2009-02-08" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("0c814336-98e2-44bc-e4df-af74639a332a" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2009-09-13" ,"2009-09-13" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("0e550768-1f74-2fae-1fac-89776e5f436c" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2009-10-04" ,"2009-10-04" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("39a0ee6f-a5c0-557c-0e9d-6a352b1bbd24" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2010-03-07" ,"2010-03-07" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("a85edd33-dcf2-805c-6693-65ed703db3f6" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2010-05-02" ,"2010-05-02" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("14916926-344f-d661-f31d-57358f7a77b7" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2010-06-06" ,"2010-06-06" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("d432611d-2b57-f9cb-f45e-7e74cae76cdd" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2010-08-01" ,"2010-08-01" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("dcd00be7-8036-6cc4-d75d-a41803ab7b7e" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2010-09-19" ,"2010-09-19" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("41fe887b-bfb7-c53d-eac5-15b8352f86f2" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2011-06-26" ,"2011-06-26" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("fb6b2d53-e2f5-d45a-a942-0e118e59c2e4" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2011-07-31" ,"2011-07-31" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("27c24fed-266a-97f3-f38e-8886f5c1c0d4" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2011-09-25" ,"2011-09-25" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("24551c49-c529-fc15-0de1-a49ba5efcd95" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2011-12-09" ,"2011-12-09" ,"185349003" ,"Encounter for \'check-up\'" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("1aebaaae-f3a0-0b9e-936c-9d6202941131" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2012-01-22" ,"2012-01-22" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("acbee35f-3b96-eef0-b317-b0c079556cea" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2012-03-04" ,"2012-03-04" ,"185345009" ,"Encounter for symptom" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("a676e9e2-c556-9da9-c064-f3609aba4a76" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2012-03-11" ,"2012-03-11" ,"702927004" ,"Urgent care clinic (procedure)" ,"9999906699" ,"Dr. Johnathon489 Block661" ,"CHELSEA MGH HEALTH CENTER MEDICAL WALK IN" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("26750ff5-f0dc-5b46-b1ed-bab37c0faa20" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2012-03-18" ,"2012-03-18" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("0d6122c6-0e7f-ad3c-26ff-cb4ac8680dbb" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2012-07-22" ,"2012-07-22" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("893a7ec1-4715-f645-449e-d43f66fcf7de" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2012-09-30" ,"2012-09-30" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("e880e778-5f59-524c-67ec-50ebf7cfdba4" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2012-10-21" ,"2012-10-21" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("a6fd5048-cf38-9317-e9e0-950b92db39a7" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2012-11-18" ,"2012-11-18" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("8e28f16b-f30a-3669-75d5-aa36f423ba30" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2013-02-17" ,"2013-02-17" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("0a51bcfa-6fc9-9d8c-51bd-6d45b47c6535" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2013-05-19" ,"2013-05-19" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("63b4e5a2-ead4-71e4-46ef-379d0a727f2c" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2013-06-16" ,"2013-06-16" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("5da9a278-5bcf-1279-bac5-7c680e64eb6e" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2013-07-21" ,"2013-07-21" ,"702927004" ,"Urgent care clinic (procedure)" ,"9999906699" ,"Dr. Johnathon489 Block661" ,"CHELSEA MGH HEALTH CENTER MEDICAL WALK IN" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("2605d4f1-ad42-5cc9-ef28-0c93d114e8c2" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2013-08-18" ,"2013-08-18" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("dbc620da-9269-8ae8-8dbe-ca4429d0b8d1" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2013-10-06" ,"2013-10-06" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("7d977bf1-41f2-326d-0508-a6296125acf7" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2014-03-16" ,"2014-03-16" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("d3c46153-4d4d-dff3-c6d0-4939c65a5155" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2014-04-13" ,"2014-04-13" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("d5e610f8-8db2-122b-991c-81f045a6d131" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2014-09-14" ,"2014-09-14" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("9726fbcd-b637-5a4e-1626-de6dad2d4fdb" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2014-10-12" ,"2014-10-12" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("f384877e-6d18-117c-9662-6cd5cd644903" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2014-10-26" ,"2014-10-26" ,"702927004" ,"Urgent care clinic (procedure)" ,"9999906699" ,"Dr. Johnathon489 Block661" ,"CHELSEA MGH HEALTH CENTER MEDICAL WALK IN" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("11b4ca80-013a-49af-9039-005b03c8876d" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2015-04-12" ,"2015-04-12" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("f5736543-2c6c-ea4d-321e-8ca82d77f419" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2015-06-07" ,"2015-06-07" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("b4cdf2e7-b553-7ff6-8724-3ea105b0627e" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2015-10-18" ,"2015-10-18" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("74d0370d-94b9-fcf0-4e96-f907a11c4a51" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2015-12-06" ,"2015-12-06" ,"702927004" ,"Urgent care clinic (procedure)" ,"9999906699" ,"Dr. Johnathon489 Block661" ,"CHELSEA MGH HEALTH CENTER MEDICAL WALK IN" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("7af37f46-89b5-8f50-f089-e942f2b2172a" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2016-01-03" ,"2016-01-03" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("f0417090-7ec9-3de7-3c1f-41dd1f56e96e" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2016-06-05" ,"2016-06-05" ,"702927004" ,"Urgent care clinic (procedure)" ,"9999906699" ,"Dr. Johnathon489 Block661" ,"CHELSEA MGH HEALTH CENTER MEDICAL WALK IN" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("10799f53-7b46-1cde-cef9-6fdfb4724e37" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2016-07-03" ,"2016-07-03" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("7ec8478b-d21e-a3d0-2617-7da516dae4bf" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2016-10-23" ,"2016-10-23" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("36ee941f-37bb-563c-89a3-42d7b14794f3" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2016-12-08" ,"2016-12-08" ,"185349003" ,"Encounter for \'check-up\'" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("21596d6f-ae28-3c74-e5ef-a260d9499d69" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2017-03-26" ,"2017-03-26" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("372ca61a-068f-1f17-502a-32c1bea855e9" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2017-04-30" ,"2017-04-30" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("56c15d5c-93a9-4567-7372-6e41a9ea907f" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2017-06-25" ,"2017-06-25" ,"702927004" ,"Urgent care clinic (procedure)" ,"9999906699" ,"Dr. Johnathon489 Block661" ,"CHELSEA MGH HEALTH CENTER MEDICAL WALK IN" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("21001334-7832-54a7-1abe-a2cf0ce73d2b" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2017-10-22" ,"2017-10-22" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("0a153f82-4425-2d3d-6399-bea96214244c" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2017-11-05" ,"2017-11-05" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("596c7508-dd3a-207f-944c-7fe3a9011d11" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2017-11-26" ,"2017-11-26" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("d3a6d483-8df2-37e6-1312-8a3592d8e74b" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2017-12-24" ,"2017-12-24" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("2fe563f6-394d-8d6d-6bd0-c8204538249f" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2018-01-21" ,"2018-01-21" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("ca34030b-c0ab-b22f-1287-d8f56124ad32" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2018-05-29" ,"2018-05-29" ,"185349003" ,"Encounter for \'check-up\'" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("55946ac1-5232-3be1-1ea5-b3816f43cb99" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2018-07-22" ,"2018-07-22" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("d36e1d50-5d74-b7b8-5efa-d30445c48c43" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2018-11-11" ,"2018-11-11" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("32d90488-1289-c183-ea54-2551fa7b015d" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2019-01-20" ,"2019-01-20" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("6bf265a2-6625-5170-9e95-d8118d9d2c39" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2019-02-17" ,"2019-02-17" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("92fdaecd-2e13-4bb7-9369-89f7bc2432f4" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2019-08-18" ,"2019-08-18" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("e24225db-1e70-d455-d00a-d8818a851514" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2019-11-17" ,"2019-11-17" ,"162673000" ,"General examination of patient (procedure)" ,"9999954489" ,"Dr. Marian936 Wiza601" ,"PCP112182" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("84df56ac-afdd-40cb-b2fd-35efcef7ecd0" ,"9e84e569-7adc-ff42-ccdb-9fe9c23842a6" ,"2019-12-01" ,"2019-12-01" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999729" ,"Dr. Damaris45 Borer986" ,"HALLMARK HEALTH SYSTEM" ,"AMB");',
# ...
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("7c816635-1d17-5549-9fc8-ef4e05592f94" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2017-04-27" ,"2017-04-27" ,"390906007" ,"Hypertension follow-up encounter" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("47983a4f-ce0e-f6c6-977d-172f7249a4d7" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2017-06-26" ,"2017-06-26" ,"390906007" ,"Hypertension follow-up encounter" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("8c4387d3-7313-fedb-d344-ff78d69d7c88" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2017-10-07" ,"2017-10-07" ,"185345009" ,"Encounter for symptom" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("e4edfbb9-d8c3-6ea7-a109-c2f342b5dcd6" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2018-02-02" ,"2018-02-02" ,"162673000" ,"General examination of patient (procedure)" ,"9999991329" ,"Dr. Ozzie259 Bahringer146" ,"PCP12425" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("5f748935-9a31-ada2-4fa0-0de42cf2c536" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2018-11-17" ,"2018-11-17" ,"50849002" ,"Emergency room admission (procedure)" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"EMER");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("dfd15992-98f3-00ed-d83d-93272f3ce8ac" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2019-01-04" ,"2019-01-04" ,"185349003" ,"Encounter for \'check-up\'" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("25f7d398-d23f-90be-8dc9-2fdf4b23e0bc" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2019-02-08" ,"2019-02-08" ,"162673000" ,"General examination of patient (procedure)" ,"9999991329" ,"Dr. Ozzie259 Bahringer146" ,"PCP12425" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("a2515cd4-f2ae-19ea-beb6-f2f5239bb782" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2020-01-10" ,"2020-01-10" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("9e22b314-dde2-3a4b-c5a2-2461ede5e036" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2020-02-14" ,"2020-02-14" ,"162673000" ,"General examination of patient (procedure)" ,"9999991329" ,"Dr. Ozzie259 Bahringer146" ,"PCP12425" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("231e6768-b0ae-c2bb-94c4-bbc0093295cc" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2020-02-28" ,"2020-02-28" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("ec8813d6-54c0-bde6-95bd-a001c98922fc" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2020-03-13" ,"2020-03-13" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("99d10dc7-98fa-8d59-3f41-979655ea3421" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2020-04-10" ,"2020-04-10" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("c7d04388-2d2e-771d-fad4-0f43fd7ef536" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2020-05-08" ,"2020-05-08" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("e075a658-5e4c-c8f8-3b65-e808d2356818" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2020-07-10" ,"2020-07-10" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("8d8b6a8e-0d9c-33e3-057e-086b18ec3e71" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2020-08-07" ,"2020-08-07" ,"702927004" ,"Urgent care clinic (procedure)" ,"9999906689" ,"Dr. Evan94 Durgan499" ,"HARVARD VANGUARD BRAINTREE PRACTICE URGENT CARE" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("7e788245-4f78-ddde-b5d8-5cd7fe04837c" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2020-09-11" ,"2020-09-11" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("32555628-4708-e1c0-9430-4f17d7f0dd44" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2020-11-06" ,"2020-11-06" ,"702927004" ,"Urgent care clinic (procedure)" ,"9999906689" ,"Dr. Evan94 Durgan499" ,"HARVARD VANGUARD BRAINTREE PRACTICE URGENT CARE" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("fb475cd5-489d-7234-1298-2e560373c160" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2021-01-08" ,"2021-01-08" ,"702927004" ,"Urgent care clinic (procedure)" ,"9999906689" ,"Dr. Evan94 Durgan499" ,"HARVARD VANGUARD BRAINTREE PRACTICE URGENT CARE" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("11e78f11-abb8-e244-fa5e-f89fee268ec3" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2021-02-19" ,"2021-02-19" ,"162673000" ,"General examination of patient (procedure)" ,"9999991329" ,"Dr. Ozzie259 Bahringer146" ,"PCP12425" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("53124aac-e265-fb4c-b8a5-b302649a3060" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2021-03-05" ,"2021-03-05" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("a49a603c-8bab-baf2-68c6-085a7209944e" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2021-03-26" ,"2021-03-26" ,"33879002" ,"Administration of vaccine to produce active immunity (procedure)" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("64471737-85ca-ee07-de3b-c557fed86eb7" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2021-04-09" ,"2021-04-09" ,"702927004" ,"Urgent care clinic (procedure)" ,"9999906689" ,"Dr. Evan94 Durgan499" ,"HARVARD VANGUARD BRAINTREE PRACTICE URGENT CARE" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("2e6ec543-8fa0-ced7-8468-f29437c778bc" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2021-08-02" ,"2021-08-02" ,"185345009" ,"Encounter for symptom" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("0cac6ca8-0248-3898-7c8f-84b4a39102f6" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2021-08-13" ,"2021-08-13" ,"185349003" ,"Encounter for check up (procedure)" ,"9999999589" ,"Dr. Daren950 Nienow652" ,"SOUTH SHORE HOSPITAL" ,"AMB");',
#  'INSERT INTO encounter(encounter_id,patient_id, start_date, end_date, snomed_code, snomed_text, provider_NPI, provider_name,facility_name, facility_code) VALUES ("f0790767-f52f-6fec-f527-d6e7b8ac136b" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"2021-09-03" ,"2021-09-03" ,"702927004" ,"Urgent care clinic (procedure)" ,"9999906689" ,"Dr. Evan94 Durgan499" ,"HARVARD VANGUARD BRAINTREE PRACTICE URGENT CARE" ,"AMB");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("39c0f604-5a17-5886-b136-3b7397025c74" ,"active" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999999589" ,"558a68d2-189f-9752-bdc9-6a48bb367da0" ,"2012-07-29" ,"2001499" ,"Vitamin B 12 5 MG/ML Injectable Solution" ,"" ,"" ,"" ,"" ,"" ,"" ,"False");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("4bb4d9ef-6985-90f8-7d4f-eba1e267856f" ,"stopped" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999999589" ,"6e3d1ccc-cedf-8cc1-b1df-ed04d575450c" ,"2013-10-17" ,"562251" ,"Amoxicillin 250 MG / Clavulanate 125 MG Oral Tablet" ,"" ,"" ,"" ,"" ,"" ,"" ,"False");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("83906591-8321-4ca9-8e67-99330b41555e" ,"stopped" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999991329" ,"1febb5e0-68f9-111e-e820-b43b740ebd32" ,"2017-01-27" ,"314076" ,"lisinopril 10 MG Oral Tablet" ,"" ,"" ,"" ,"1" ,"1.0" ,"d" ,"False");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("22c62fce-0594-8d21-c2ed-59e818f18a5e" ,"stopped" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999999589" ,"3bb369e8-f0aa-9542-5f80-3e52679f9d4e" ,"2017-02-26" ,"308136" ,"amLODIPine 2.5 MG Oral Tablet" ,"" ,"" ,"" ,"1" ,"1.0" ,"d" ,"False");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("b28cb012-ac03-1013-79ec-c1c52c5a0e0f" ,"stopped" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999999589" ,"8c4387d3-7313-fedb-d344-ff78d69d7c88" ,"2017-10-07" ,"562251" ,"Amoxicillin 250 MG / Clavulanate 125 MG Oral Tablet" ,"" ,"" ,"" ,"" ,"" ,"" ,"False");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("ac1592d3-eeec-a937-f71b-2670817a77b6" ,"stopped" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999991329" ,"e4edfbb9-d8c3-6ea7-a109-c2f342b5dcd6" ,"2018-02-02" ,"314076" ,"lisinopril 10 MG Oral Tablet" ,"" ,"" ,"" ,"1" ,"1.0" ,"d" ,"False");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("aaefe297-a799-f795-8efc-94108a64aa5f" ,"stopped" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999991329" ,"e4edfbb9-d8c3-6ea7-a109-c2f342b5dcd6" ,"2018-02-02" ,"308136" ,"amLODIPine 2.5 MG Oral Tablet" ,"" ,"" ,"" ,"1" ,"1.0" ,"d" ,"False");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("94909a27-8a15-6a1c-6653-68c30d0c1aee" ,"stopped" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999999589" ,"5f748935-9a31-ada2-4fa0-0de42cf2c536" ,"2018-11-17" ,"849574" ,"Naproxen sodium 220 MG Oral Tablet" ,"Take as needed." ,"" ,"" ,"" ,"" ,"" ,"False");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("e5a978a7-3c78-f989-c588-1aebc04f34fd" ,"stopped" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999991329" ,"25f7d398-d23f-90be-8dc9-2fdf4b23e0bc" ,"2019-02-08" ,"314076" ,"lisinopril 10 MG Oral Tablet" ,"" ,"" ,"" ,"1" ,"1.0" ,"d" ,"False");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("14720f91-6df6-88b8-fc9c-5e996a509cd7" ,"stopped" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999991329" ,"25f7d398-d23f-90be-8dc9-2fdf4b23e0bc" ,"2019-02-08" ,"308136" ,"amLODIPine 2.5 MG Oral Tablet" ,"" ,"" ,"" ,"1" ,"1.0" ,"d" ,"False");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("aba09fbb-6f5a-fa5c-cd52-bd207e3d07c9" ,"stopped" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999999589" ,"a2515cd4-f2ae-19ea-beb6-f2f5239bb782" ,"2020-01-10" ,"314076" ,"lisinopril 10 MG Oral Tablet" ,"" ,"" ,"" ,"1" ,"1.0" ,"d" ,"False");',
#  'INSERT INTO med_history(rx_id, resource_status,\tpatient_id, provider_id, encounter_id, request_date, rxnorm_code, rxnorm_text, rx_text, snomed_code, snomed_text,repeat_freq,repeat_period,repeat_period_unit, as_needed) VALUES ("466c5445-1af3-56cc-f876-d32c9eca09d4" ,"stopped" ,"060e72d3-912e-55cd-0c92-5faa6cb7a6db" ,"9999999589" ,"a2515cd4-f2ae-19ea-beb6-f2f5239bb782" ,"2020-01-10" ,"308136" ,"amLODIPine 2.5 MG Oral Tablet" ,"" ,"" ,"" ,"1" ,"1.0" ,"d" ,"False");',
#  ...]

# %%
file = open('patient.txt','w')
for item in sql_list:
	file.write(item+"\n")
file.close()
